# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3

# %%
path='/home/vaibhav/Music/database.sqlite'
database=path

# %%
connect=sqlite3.connect(database)

tables=pd.read_sql("""SELECT * FROM sqlite_master WHERE type='table';""" ,connect)
tables
# Out:
#     type               name           tbl_name  rootpage  \
# 0  table    sqlite_sequence    sqlite_sequence         4
# 1  table  Player_Attributes  Player_Attributes        11
# 2  table             Player             Player        14
# 3  table              Match              Match        18
# 4  table             League             League        24
# 5  table            Country            Country        26
# 6  table               Team               Team        29
# 7  table    Team_Attributes    Team_Attributes         2
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "Player_Attributes" (\n\t`id`\tIN...
# 2  CREATE TABLE `Player` (\n\t`id`\tINTEGER PRIMA...
# 3  CREATE TABLE `Match` (\n\t`id`\tINTEGER PRIMAR...
# 4  CREATE TABLE `League` (\n\t`id`\tINTEGER PRIMA...
# 5  CREATE TABLE `Country` (\n\t`id`\tINTEGER PRIM...
# 6  CREATE TABLE "Team" (\n\t`id`\tINTEGER PRIMARY...
# ...

# %%
countries=pd.read_sql("""SELECT * FROM Country;""",connect)
countries
# Out:
#        id         name
# 0       1      Belgium
# 1    1729      England
# 2    4769       France
# 3    7809      Germany
# 4   10257        Italy
# 5   13274  Netherlands
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland

# %%
league=pd.read_sql("""SELECT * FROM League;""",connect)
league
#player=pd.read_sql("""SELECT * FROM Player;""",connect)
#player
# Out:
#        id  country_id                      name
# 0       1           1    Belgium Jupiler League
# 1    1729        1729    England Premier League
# 2    4769        4769            France Ligue 1
# 3    7809        7809     Germany 1. Bundesliga
# 4   10257       10257             Italy Serie A
# 5   13274       13274    Netherlands Eredivisie
# 6   15722       15722        Poland Ekstraklasa
# 7   17642       17642  Portugal Liga ZON Sagres
# 8   19694       19694   Scotland Premier League
# 9   21518       21518           Spain LIGA BBVA
# 10  24558       24558  Switzerland Super League

# %%
#playeratt=pd.read_sql("""SELECT * FROM Player_Attributes;""",connect)
#playeratt

# %%
league= pd.read_sql("""SELECT * FROM Match;""",connect)
league
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 0          1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1          2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2          3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3          4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4          5           1          1  2008/2009      1  2008-08-16 00:00:00
# 5          6           1          1  2008/2009      1  2008-09-24 00:00:00
# 6          7           1          1  2008/2009      1  2008-08-16 00:00:00
# 7          8           1          1  2008/2009      1  2008-08-16 00:00:00
# 8          9           1          1  2008/2009      1  2008-08-16 00:00:00
# 9         10           1          1  2008/2009     10  2008-11-01 00:00:00
# 10        11           1          1  2008/2009     10  2008-10-31 00:00:00
# ...

# %%
teamein=pd.read_sql("""SELECT * FROM Team;""",connect)
teamein
# Out:
#         id  team_api_id  team_fifa_api_id           team_long_name  \
# 0        1         9987             673.0                 KRC Genk
# 1        2         9993             675.0             Beerschot AC
# 2        3        10000           15005.0         SV Zulte-Waregem
# 3        4         9994            2007.0         Sporting Lokeren
# 4        5         9984            1750.0        KSV Cercle Brugge
# 5        6         8635             229.0           RSC Anderlecht
# 6        7         9991             674.0                 KAA Gent
# 7        8         9998            1747.0                RAEC Mons
# 8        9         7947               NaN            FCV Dender EH
# 9       10         9985             232.0        Standard de Liège
# 10      11         8203          110724.0              KV Mechelen
# 11      12         8342             231.0           Club Brugge KV
# 12      13         9999             546.0            KSV Roeselare
# ...

# %%
mat=pd.read_sql("""SELECT Match.id,Country.id,home_team_api_id,Country.name AS Cname,League.name AS lname,match_api_id,date,stage FROM Match JOIN Country ON Country.id=Match.country_id JOIN League ON League.id=Match.league_id WHERE country_name="Spain" ORDER by date LIMIT 10;""",connect)
mat
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1399             else:
# -> 1400                 cur.execute(*args)
#    1401             return cur
#
# OperationalError: no such column: country_name
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-49-2befd0ab817d> in <module>()
# ----> 1 mat=pd.read_sql("""SELECT Match.id,Country.id,home_team_api_id,Country.name AS Cname,League.name AS lname,match_api_id,date,stage FROM Match JOIN Country ON Country.id=Match.country_id JOIN League ON League.id=Match.league_id WHERE country_name="Spain" ORDER by date LIMIT 10;""",connect)
#       2 mat
#
# ...

# %%
leagues_by_season
